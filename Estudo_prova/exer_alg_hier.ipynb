# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusHenriqueDaSilva/data_science/blob/main/exer_alg_hier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split

# %%
# Data understanding
DATA = pd.read_csv('/content/agrupamento.csv')
DATA.head()
# Out:
#          x0        x1        x2        x3        x4
# 0  5.447043  6.319084  2.664620  6.568743  4.802295
# 1  4.875562  4.796801  2.154231  6.832907  5.321401
# 2  5.582920  5.060775  1.895917  6.004299  6.330105
# 3  6.370727  3.717727  1.729007  5.923414  4.533557
# 4  4.789262  4.510056  0.669330  7.731273  4.272356

# %%
def generate_metadata(dataframe):

    metadata2 = pd.DataFrame({
        'nome_variavel': dataframe.columns,
        'tipo': dataframe.dtypes,
        'qt_nulos': dataframe.isnull().sum(),
        'percent_nulos': round((dataframe.isnull().sum() / len(dataframe))* 100,2),
        'cardinalidade': dataframe.nunique(),
    })
    metadata2=metadata2.sort_values(by='tipo')
    metadata2 = metadata2.reset_index(drop=True)

    return metadata2

metadados = generate_metadata(DATA)
metadados
# Out:
#   nome_variavel     tipo  qt_nulos  percent_nulos  cardinalidade
# 0            x0  float64         0            0.0             85
# 1            x1  float64         0            0.0             85
# 2            x2  float64         0            0.0             85
# 3            x3  float64         0            0.0             85
# 4            x4  float64         0            0.0             85

# %%
DATA.describe()
# Out:
#               x0         x1         x2         x3         x4
# count  85.000000  85.000000  85.000000  85.000000  85.000000
# mean    2.817069   2.748916   2.035626   4.360334   2.628691
# std     1.804590   2.496234   2.471162   3.590181   2.012583
# min     0.040614  -2.268887  -0.595652  -0.257424  -1.013659
# 25%     1.087289   0.886838   0.393542   0.736619   0.439842
# 50%     3.245579   2.148492   1.244704   5.923414   3.178894
# 75%     4.443743   5.099830   2.493123   7.858465   4.030374
# max     6.421292   7.094901   7.938085   9.464671   6.330105

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

X = DATA

# Calcular a ligação simples
Z = linkage(X, method='single')

# Plotar o dendrograma
plt.figure(figsize=(18, 6))
plt.title('Dendrograma - Ligação Simples')
dendrogram(Z)
plt.xlabel('Índice dos pontos')
plt.ylabel('Distância')
plt.show()

# %%
estudo = pd.DataFrame(grid.cv_results_ )
estudo['mean_train_score']
# Out:
# 0    0.879089
# Name: mean_train_score, dtype: float64

# %%
estudo['mean_test_score']
# Out:
# 0    0.876574
# Name: mean_test_score, dtype: float64

# %%
estudo.iloc[:,7:]
# Out:
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -3.404123          -4.405335          -2.603153           -4.00485
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           -3.20388          -3.604365           -1.60194          -3.003638
#
#    split9_test_score  mean_test_score  ...  split2_train_score  \
# 0          -3.003638        -3.163832  ...       -2.220446e-16
#
#    split3_train_score  split4_train_score  split5_train_score  \
# 0       -2.220446e-16       -2.220446e-16       -2.220446e-16
#
#    split6_train_score  split7_train_score  split8_train_score  \
# 0       -2.220446e-16       -2.220446e-16       -2.220446e-16
#
#    split9_train_score  mean_train_score  std_train_score
# 0       -2.220446e-16     -2.220446e-16              0.0
#
# [1 rows x 24 columns]
