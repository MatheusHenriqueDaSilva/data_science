# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusHenriqueDaSilva/data_science/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
from sklearn.model_selection import train_test_split

# %%
tamanho_campos=[2,8,2,12,3,12,10,3,4,13,13,13,13,13,13,13,5,18,18,13,1,8,7,13,12,3]
ANOS=[2018,2019,2020,2021,2022,2023,2024]
dados = {}  # Dicionário para armazenar os DataFrames

for ano in ANOS:
  dados[f'data_{ano}'] = pd.read_fwf(f'/content/COTAHIST_A{ano}.TXT', widths=tamanho_campos, header=0)

  ## Nomear as colunas

  dados[f'data_{ano}'].columns = [
  "tipo_registro",
  "data_pregao",
  "cod_bdi",
  "cod_negociacao",
  "tipo_mercado",
  "noma_empresa",
  "especificacao_papel",
  "prazo_dias_merc_termo",
  "moeda_referencia",
  "preco_abertura",
  "preco_maximo",
  "preco_minimo",
  "preco_medio",
  "preco_ultimo_negocio",
  "preco_melhor_oferta_compra",
  "preco_melhor_oferta_venda",
  "numero_negocios",
  "quantidade_papeis_negociados",
  "volume_total_negociado",
  "preco_exercicio",
  "ìndicador_correcao_precos",
  "data_vencimento" ,
  "fator_cotacao",
  "preco_exercicio_pontos",
  "codigo_isin",
  "num_distribuicao_papel"]

  # Eliminar a última linha
  linha=len(dados[f'data_{ano}']["data_pregao"])
  dados[f'data_{ano}']=dados[f'data_{ano}'].drop(linha-1)

  # Ajustar valores com virgula (dividir os valores dessas colunas por 100)
  listaVirgula=[
  "preco_abertura",
  "preco_maximo",
  "preco_minimo",
  "preco_medio",
  "preco_ultimo_negocio",
  "preco_melhor_oferta_compra",
  "preco_melhor_oferta_venda",
  "volume_total_negociado",
  "preco_exercicio",
  "preco_exercicio_pontos"
  ]

  for coluna in listaVirgula:
      dados[f'data_{ano}'][coluna]=[i/100. for i in dados[f'data_{ano}'][coluna]]

  dados[f'data_{ano}'] = dados[f'data_{ano}'][(dados[f'data_{ano}']['tipo_mercado']==10) & (dados[f'data_{ano}']['cod_negociacao'] == 'ITUB4')]

# %%
data_itub4 =  pd.concat([dados[f'data_2018'],dados[f'data_2019'],dados[f'data_2020'],dados[f'data_2021'],dados[f'data_2022'],dados[f'data_2023'],dados[f'data_2024']], axis = 0).reset_index()

# %%
data_itub4.tail(
)
# Out:
#         index  tipo_registro data_pregao  cod_bdi cod_negociacao  \
# 1681  1347607              1    20241007      2.0          ITUB4
# 1682  1349245              1    20241008      2.0          ITUB4
# 1683  1351069              1    20241009      2.0          ITUB4
# 1684  1352647              1    20241010      2.0          ITUB4
# 1685  1354390              1    20241011      2.0          ITUB4
#
#       tipo_mercado  noma_empresa especificacao_papel  prazo_dias_merc_termo  \
# 1681            10  ITAUUNIBANCO          PN  EJ  N1                    NaN
# 1682            10  ITAUUNIBANCO          PN  EJ  N1                    NaN
# 1683            10  ITAUUNIBANCO          PN  EJ  N1                    NaN
# 1684            10  ITAUUNIBANCO          PN  EJ  N1                    NaN
# 1685            10  ITAUUNIBANCO          PN      N1                    NaN
#
#      moeda_referencia  ...  data_vencimento  fator_cotacao  \
# 1681               R$  ...       99991231.0            1.0
# 1682               R$  ...       99991231.0            1.0
# 1683               R$  ...       99991231.0            1.0
# 1684               R$  ...       99991231.0            1.0
# 1685               R$  ...       99991231.0            1.0
#
#       preco_exercicio_pontos   codigo_isin  num_distribuicao_papel  \
# 1681                     0.0  BRITUBACNPR1                   342.0
# 1682                     0.0  BRITUBACNPR1                   342.0
# 1683                     0.0  BRITUBACNPR1                   342.0
# 1684                     0.0  BRITUBACNPR1                   342.0
# 1685                     0.0  BRITUBACNPR1                   342.0
#
#       var_preco_ultimo_negocio  max_preco_ultimo_negocio0  \
# 1681                       0.0                      35.72
# 1682                       0.0                      35.72
# 1683                       0.0                      35.35
# 1684                       0.0                      35.35
# 1685                       0.0                      35.35
#
#       max_preco_ultimo_negocio1  max_preco_ultimo_negocio20  classificacao
# 1681                      36.11                       37.48              0
# 1682                      35.72                       37.48              0
# 1683                      35.72                       37.48              0
# 1684                      35.35                       37.38              0
# 1685                      35.35                       37.38              0
#
# [5 rows x 32 columns]

# %%
def generate_metadata(dataframe):

    metadata2 = pd.DataFrame({
        'nome_variavel': dataframe.columns,
        'tipo': dataframe.dtypes,
        'qt_nulos': dataframe.isnull().sum(),
        'percent_nulos': round((dataframe.isnull().sum() / len(dataframe))* 100,2),
        'cardinalidade': dataframe.nunique(),
    })
    metadata2=metadata2.sort_values(by='tipo')
    metadata2 = metadata2.reset_index(drop=True)

    return metadata2

metadados = generate_metadata(data_itub4)
metadados.head(50)
# Out:
#                    nome_variavel     tipo  qt_nulos  percent_nulos  \
# 0                          index    int64         0           0.00
# 1                   tipo_mercado    int64         0           0.00
# 2                  classificacao    int64         0           0.00
# 3                  tipo_registro    int64         0           0.00
# 4                        cod_bdi  float64         0           0.00
# 5      max_preco_ultimo_negocio1  float64         5           0.30
# 6      max_preco_ultimo_negocio0  float64         4           0.24
# 7       var_preco_ultimo_negocio  float64         0           0.00
# 8         num_distribuicao_papel  float64         0           0.00
# 9         preco_exercicio_pontos  float64         0           0.00
# 10                 fator_cotacao  float64         0           0.00
# 11               data_vencimento  float64         0           0.00
# 12     ìndicador_correcao_precos  float64         0           0.00
# 13               preco_exercicio  float64         0           0.00
# 14        volume_total_negociado  float64         0           0.00
# 15  quantidade_papeis_negociados  float64         0           0.00
# 16               numero_negocios  float64         0           0.00
# 17    max_preco_ultimo_negocio20  float64        24           1.42
# 18          preco_ultimo_negocio  float64         0           0.00
# 19                   preco_medio  float64         0           0.00
# 20                  preco_minimo  float64         0           0.00
# 21                  preco_maximo  float64         0           0.00
# 22                preco_abertura  float64         0           0.00
# 23         prazo_dias_merc_termo  float64      1686         100.00
# 24     preco_melhor_oferta_venda  float64         0           0.00
# 25    preco_melhor_oferta_compra  float64         0           0.00
# 26                   data_pregao   object         0           0.00
# 27              moeda_referencia   object         0           0.00
# 28                   codigo_isin   object         0           0.00
# 29           especificacao_papel   object         0           0.00
# 30                  noma_empresa   object         0           0.00
# 31                cod_negociacao   object         0           0.00
#
#     cardinalidade
# 0            1686
# 1               1
# 2               3
# 3               1
# 4               1
# 5             615
# 6             615
# 7            1665
# 8             111
# 9               1
# 10              1
# 11              1
# 12              1
# 13              1
# 14           1686
# 15           1682
# 16           1663
# 17            606
# 18           1145
# 19           1164
# 20           1158
# 21           1139
# 22           1125
# 23              0
# 24           1132
# 25           1148
# 26           1686
# 27              1
# 28              1
# 29              8
# 30              1
# 31              1

# %% [markdown]
# # Nova seção

# %%
#data_itub4['var_preco_ultimo_negocio'] = data_itub4['preco_ultimo_negocio'].pct_change(-5).fillna(0)
data_itub4['var_preco_ultimo_negocio']  = (data_itub4['preco_ultimo_negocio'].diff(-20).fillna(0)/data_itub4['preco_ultimo_negocio'])

# %%
def criar_target(valor):
  if valor >=0.01:
    return 1
  elif valor <=-0.01:
    return -1
  else:
    return 0

data_itub4['classificacao'] = data_itub4['var_preco_ultimo_negocio'].apply(criar_target)

lista_spec = ['quantidade_papeis_negociados','numero_negocios','preco_melhor_oferta_venda','preco_melhor_oferta_compra',
              'preco_medio','preco_minimo','preco_maximo','preco_abertura','num_distribuicao_papel','preco_ultimo_negocio']
target = data_itub4['classificacao']
data_itub4_clean = data_itub4.loc[:,lista_spec].reset_index(drop=True)
data_itub4_clean.head(20)
# Out:
#     quantidade_papeis_negociados  numero_negocios  preco_melhor_oferta_venda  \
# 0                     11100600.0          30810.0                      43.88
# 1                     14863800.0          18377.0                      44.18
# 2                     15481700.0          28294.0                      45.20
# 3                     10478300.0          19882.0                      45.23
# 4                      8472100.0          20228.0                      45.08
# 5                     14272000.0          25518.0                      44.59
# 6                      9067700.0          23109.0                      44.52
# 7                     10364300.0          21941.0                      45.37
# 8                      6854900.0          19090.0                      45.33
# 9                      7275800.0          10779.0                      45.61
# 10                     8756700.0          19335.0                      46.04
# 11                     9612600.0          27904.0                      46.80
# 12                     8660600.0          21456.0                      46.68
# 13                     7388700.0          15788.0                      47.07
# 14                    11913100.0          26158.0                      48.24
# 15                    19467500.0          28371.0                      48.06
# 16                    14738100.0          34001.0                      50.37
# 17                    31624400.0          62420.0                      53.12
# 18                    22086900.0          27899.0                      51.78
# 19                    16963500.0          33131.0                      51.49
#
#     preco_melhor_oferta_compra  preco_medio  preco_minimo  preco_maximo  \
# 0                        43.79        43.56         42.80         43.88
# 1                        44.17        44.01         43.57         44.34
# 2                        45.10        44.99         44.25         45.30
# 3                        45.20        45.08         44.60         45.32
# 4                        45.07        45.06         44.78         45.32
# 5                        44.54        44.67         44.41         45.00
# 6                        44.44        44.43         44.16         44.60
# 7                        45.36        45.02         44.60         45.37
# 8                        45.26        45.16         44.97         45.42
# 9                        45.59        45.54         45.41         45.62
# 10                       46.03        46.01         45.45         46.23
# 11                       46.78        46.53         45.81         46.95
# 12                       46.67        46.78         46.48         47.12
# 13                       47.06        46.89         46.63         47.18
# 14                       48.23        47.82         46.97         48.23
# 15                       48.05        48.25         47.91         48.60
# 16                       50.21        49.47         48.40         50.43
# 17                       52.96        52.36         51.01         53.12
# 18                       51.69        52.14         51.69         52.86
# 19                       51.48        51.20         50.80         51.73
#
#     preco_abertura  num_distribuicao_papel  preco_ultimo_negocio
# 0            42.80                   232.0                 43.88
# 1            43.90                   232.0                 44.18
# 2            44.25                   232.0                 45.10
# 3            45.12                   232.0                 45.23
# 4            45.06                   232.0                 45.08
# 5            44.96                   232.0                 44.59
# 6            44.38                   232.0                 44.44
# 7            44.70                   232.0                 45.37
# 8            45.16                   232.0                 45.33
# 9            45.49                   232.0                 45.61
# 10           45.50                   232.0                 46.03
# 11           46.01                   232.0                 46.79
# 12           46.70                   232.0                 46.68
# 13           46.90                   232.0                 47.06
# 14           47.06                   232.0                 48.23
# 15           48.00                   232.0                 48.06
# 16           48.44                   232.0                 50.37
# 17           51.20                   232.0                 53.12
# 18           52.64                   232.0                 51.69
# 19           51.40                   232.0                 51.49

# %%
for i in lista_spec:
  data_itub4_clean[f'max20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).max().fillna(0)
  data_itub4_clean[f'max60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).max().fillna(0)
  data_itub4_clean[f'max120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).max().fillna(0)
  data_itub4_clean[f'max240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).max().fillna(0)
  data_itub4_clean[f'max480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).max().fillna(0)
  data_itub4_clean[f'max720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).max().fillna(0)

  data_itub4_clean[f'min20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).min().fillna(0)
  data_itub4_clean[f'min60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).min().fillna(0)
  data_itub4_clean[f'min120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).min().fillna(0)
  data_itub4_clean[f'min240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).min().fillna(0)
  data_itub4_clean[f'min480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).min().fillna(0)
  data_itub4_clean[f'min720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).min().fillna(0)

  data_itub4_clean[f'media20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).mean().fillna(0)
  data_itub4_clean[f'media60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).mean().fillna(0)
  data_itub4_clean[f'media120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).mean().fillna(0)
  data_itub4_clean[f'media240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).mean().fillna(0)
  data_itub4_clean[f'media480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).mean().fillna(0)
  data_itub4_clean[f'media720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).mean().fillna(0)

data_itub4_clean = data_itub4_clean.iloc[721:,:].reset_index(drop=True)

for i in lista_spec:
  data_itub4_clean[f'razmax20_60_{i}'] = data_itub4_clean[f'max20_{i}']/data_itub4_clean[f'max60_{i}']
  data_itub4_clean[f'razmax60_120_{i}'] = data_itub4_clean[f'max60_{i}']/data_itub4_clean[f'max120_{i}']
  data_itub4_clean[f'razmax120_240_{i}'] = data_itub4_clean[f'max120_{i}']/data_itub4_clean[f'max240_{i}']
  data_itub4_clean[f'razmax240_480_{i}'] = data_itub4_clean[f'max240_{i}']/data_itub4_clean[f'max480_{i}']
  data_itub4_clean[f'razmax20_120_{i}'] = data_itub4_clean[f'max20_{i}']/data_itub4_clean[f'max120_{i}']
  data_itub4_clean[f'razmax60_240{i}'] = data_itub4_clean[f'max60_{i}']/data_itub4_clean[f'max240_{i}']
  data_itub4_clean[f'razmax120_480{i}'] = data_itub4_clean[f'max120_{i}']/data_itub4_clean[f'max480_{i}']
  data_itub4_clean[f'razmax20_240{i}'] = data_itub4_clean[f'max20_{i}']/data_itub4_clean[f'max240_{i}']
  data_itub4_clean[f'razmax60_480{i}'] = data_itub4_clean[f'max60_{i}']/data_itub4_clean[f'max480_{i}']
  data_itub4_clean[f'razmax20_480{i}'] = data_itub4_clean[f'max20_{i}']/data_itub4_clean[f'max480_{i}']

  data_itub4_clean[f'razmin20_60_{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min60_{i}']
  data_itub4_clean[f'razmin60_120_{i}'] = data_itub4_clean[f'min60_{i}']/data_itub4_clean[f'min120_{i}']
  data_itub4_clean[f'razmin120_240_{i}'] = data_itub4_clean[f'min120_{i}']/data_itub4_clean[f'min240_{i}']
  data_itub4_clean[f'razmin240_480_{i}'] = data_itub4_clean[f'min240_{i}']/data_itub4_clean[f'min480_{i}']
  data_itub4_clean[f'razmin20_120_{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min120_{i}']
  data_itub4_clean[f'razmin60_240{i}'] = data_itub4_clean[f'min60_{i}']/data_itub4_clean[f'min240_{i}']
  data_itub4_clean[f'razmin120_480{i}'] = data_itub4_clean[f'min120_{i}']/data_itub4_clean[f'min480_{i}']
  data_itub4_clean[f'razmin20_240{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min240_{i}']
  data_itub4_clean[f'razmin60_480{i}'] = data_itub4_clean[f'min60_{i}']/data_itub4_clean[f'min480_{i}']
  data_itub4_clean[f'razmin20_480{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min480_{i}']

  data_itub4_clean[f'razmedia20_60_{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media60_{i}']
  data_itub4_clean[f'razmedia60_120_{i}'] = data_itub4_clean[f'media60_{i}']/data_itub4_clean[f'media120_{i}']
  data_itub4_clean[f'razmedia120_240_{i}'] = data_itub4_clean[f'media120_{i}']/data_itub4_clean[f'media240_{i}']
  data_itub4_clean[f'razmedia240_480_{i}'] = data_itub4_clean[f'media240_{i}']/data_itub4_clean[f'media480_{i}']
  data_itub4_clean[f'razmedia20_120_{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media120_{i}']
  data_itub4_clean[f'razmedia60_240{i}'] = data_itub4_clean[f'media60_{i}']/data_itub4_clean[f'media240_{i}']
  data_itub4_clean[f'razmedia120_480{i}'] = data_itub4_clean[f'media120_{i}']/data_itub4_clean[f'media480_{i}']
  data_itub4_clean[f'razmedia20_240{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media240_{i}']
  data_itub4_clean[f'razmedia60_480{i}'] = data_itub4_clean[f'media60_{i}']/data_itub4_clean[f'media480_{i}']
  data_itub4_clean[f'razmedia20_480{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media480_{i}']

#.sort_values(by='data_pregao')
data_itub4_clean.tail(10)
# Out:
# <ipython-input-46-4f70f7c98425>:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'max720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).max().fillna(0)
# <ipython-input-46-4f70f7c98425>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'min720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).min().fillna(0)
# <ipython-input-46-4f70f7c98425>:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media20_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=20).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media60_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=60).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media120_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=120).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media240_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=240).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media480_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=480).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'media720_{i}'] = data_itub4_clean[f'{i}'].shift(0).rolling(window=720).mean().fillna(0)
# <ipython-input-46-4f70f7c98425>:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax20_480{i}'] = data_itub4_clean[f'max20_{i}']/data_itub4_clean[f'max480_{i}']
# <ipython-input-46-4f70f7c98425>:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin20_60_{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min60_{i}']
# <ipython-input-46-4f70f7c98425>:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin60_120_{i}'] = data_itub4_clean[f'min60_{i}']/data_itub4_clean[f'min120_{i}']
# <ipython-input-46-4f70f7c98425>:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin120_240_{i}'] = data_itub4_clean[f'min120_{i}']/data_itub4_clean[f'min240_{i}']
# <ipython-input-46-4f70f7c98425>:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin240_480_{i}'] = data_itub4_clean[f'min240_{i}']/data_itub4_clean[f'min480_{i}']
# <ipython-input-46-4f70f7c98425>:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin20_120_{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min120_{i}']
# <ipython-input-46-4f70f7c98425>:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin60_240{i}'] = data_itub4_clean[f'min60_{i}']/data_itub4_clean[f'min240_{i}']
# <ipython-input-46-4f70f7c98425>:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin120_480{i}'] = data_itub4_clean[f'min120_{i}']/data_itub4_clean[f'min480_{i}']
# <ipython-input-46-4f70f7c98425>:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin20_240{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min240_{i}']
# <ipython-input-46-4f70f7c98425>:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin60_480{i}'] = data_itub4_clean[f'min60_{i}']/data_itub4_clean[f'min480_{i}']
# <ipython-input-46-4f70f7c98425>:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin20_480{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min480_{i}']
# <ipython-input-46-4f70f7c98425>:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia20_60_{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media60_{i}']
# <ipython-input-46-4f70f7c98425>:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia60_120_{i}'] = data_itub4_clean[f'media60_{i}']/data_itub4_clean[f'media120_{i}']
# <ipython-input-46-4f70f7c98425>:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia120_240_{i}'] = data_itub4_clean[f'media120_{i}']/data_itub4_clean[f'media240_{i}']
# <ipython-input-46-4f70f7c98425>:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia240_480_{i}'] = data_itub4_clean[f'media240_{i}']/data_itub4_clean[f'media480_{i}']
# <ipython-input-46-4f70f7c98425>:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia20_120_{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media120_{i}']
# <ipython-input-46-4f70f7c98425>:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia60_240{i}'] = data_itub4_clean[f'media60_{i}']/data_itub4_clean[f'media240_{i}']
# <ipython-input-46-4f70f7c98425>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia120_480{i}'] = data_itub4_clean[f'media120_{i}']/data_itub4_clean[f'media480_{i}']
# <ipython-input-46-4f70f7c98425>:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia20_240{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media240_{i}']
# <ipython-input-46-4f70f7c98425>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia60_480{i}'] = data_itub4_clean[f'media60_{i}']/data_itub4_clean[f'media480_{i}']
# <ipython-input-46-4f70f7c98425>:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia20_480{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media480_{i}']
# <ipython-input-46-4f70f7c98425>:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax20_60_{i}'] = data_itub4_clean[f'max20_{i}']/data_itub4_clean[f'max60_{i}']
# <ipython-input-46-4f70f7c98425>:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax60_120_{i}'] = data_itub4_clean[f'max60_{i}']/data_itub4_clean[f'max120_{i}']
# <ipython-input-46-4f70f7c98425>:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax120_240_{i}'] = data_itub4_clean[f'max120_{i}']/data_itub4_clean[f'max240_{i}']
# <ipython-input-46-4f70f7c98425>:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax240_480_{i}'] = data_itub4_clean[f'max240_{i}']/data_itub4_clean[f'max480_{i}']
# <ipython-input-46-4f70f7c98425>:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax20_120_{i}'] = data_itub4_clean[f'max20_{i}']/data_itub4_clean[f'max120_{i}']
# <ipython-input-46-4f70f7c98425>:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax60_240{i}'] = data_itub4_clean[f'max60_{i}']/data_itub4_clean[f'max240_{i}']
# <ipython-input-46-4f70f7c98425>:32: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax120_480{i}'] = data_itub4_clean[f'max120_{i}']/data_itub4_clean[f'max480_{i}']
# <ipython-input-46-4f70f7c98425>:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax20_240{i}'] = data_itub4_clean[f'max20_{i}']/data_itub4_clean[f'max240_{i}']
# <ipython-input-46-4f70f7c98425>:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax60_480{i}'] = data_itub4_clean[f'max60_{i}']/data_itub4_clean[f'max480_{i}']
# <ipython-input-46-4f70f7c98425>:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax20_480{i}'] = data_itub4_clean[f'max20_{i}']/data_itub4_clean[f'max480_{i}']
# <ipython-input-46-4f70f7c98425>:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin20_60_{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min60_{i}']
# <ipython-input-46-4f70f7c98425>:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin60_120_{i}'] = data_itub4_clean[f'min60_{i}']/data_itub4_clean[f'min120_{i}']
# ...
# <ipython-input-46-4f70f7c98425>:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmax20_480{i}'] = data_itub4_clean[f'max20_{i}']/data_itub4_clean[f'max480_{i}']
# <ipython-input-46-4f70f7c98425>:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin20_60_{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min60_{i}']
# <ipython-input-46-4f70f7c98425>:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin60_120_{i}'] = data_itub4_clean[f'min60_{i}']/data_itub4_clean[f'min120_{i}']
# <ipython-input-46-4f70f7c98425>:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin120_240_{i}'] = data_itub4_clean[f'min120_{i}']/data_itub4_clean[f'min240_{i}']
# <ipython-input-46-4f70f7c98425>:40: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin240_480_{i}'] = data_itub4_clean[f'min240_{i}']/data_itub4_clean[f'min480_{i}']
# <ipython-input-46-4f70f7c98425>:41: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin20_120_{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min120_{i}']
# <ipython-input-46-4f70f7c98425>:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin60_240{i}'] = data_itub4_clean[f'min60_{i}']/data_itub4_clean[f'min240_{i}']
# <ipython-input-46-4f70f7c98425>:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin120_480{i}'] = data_itub4_clean[f'min120_{i}']/data_itub4_clean[f'min480_{i}']
# <ipython-input-46-4f70f7c98425>:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin20_240{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min240_{i}']
# <ipython-input-46-4f70f7c98425>:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin60_480{i}'] = data_itub4_clean[f'min60_{i}']/data_itub4_clean[f'min480_{i}']
# <ipython-input-46-4f70f7c98425>:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmin20_480{i}'] = data_itub4_clean[f'min20_{i}']/data_itub4_clean[f'min480_{i}']
# <ipython-input-46-4f70f7c98425>:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia20_60_{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media60_{i}']
# <ipython-input-46-4f70f7c98425>:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia60_120_{i}'] = data_itub4_clean[f'media60_{i}']/data_itub4_clean[f'media120_{i}']
# <ipython-input-46-4f70f7c98425>:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia120_240_{i}'] = data_itub4_clean[f'media120_{i}']/data_itub4_clean[f'media240_{i}']
# <ipython-input-46-4f70f7c98425>:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia240_480_{i}'] = data_itub4_clean[f'media240_{i}']/data_itub4_clean[f'media480_{i}']
# <ipython-input-46-4f70f7c98425>:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia20_120_{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media120_{i}']
# <ipython-input-46-4f70f7c98425>:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia60_240{i}'] = data_itub4_clean[f'media60_{i}']/data_itub4_clean[f'media240_{i}']
# <ipython-input-46-4f70f7c98425>:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia120_480{i}'] = data_itub4_clean[f'media120_{i}']/data_itub4_clean[f'media480_{i}']
# <ipython-input-46-4f70f7c98425>:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia20_240{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media240_{i}']
# <ipython-input-46-4f70f7c98425>:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia60_480{i}'] = data_itub4_clean[f'media60_{i}']/data_itub4_clean[f'media480_{i}']
# <ipython-input-46-4f70f7c98425>:57: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_itub4_clean[f'razmedia20_480{i}'] = data_itub4_clean[f'media20_{i}']/data_itub4_clean[f'media480_{i}']
#      quantidade_papeis_negociados  numero_negocios  preco_melhor_oferta_venda  \
# 955                    25147200.0          32663.0                      36.12
# 956                    26606300.0          45879.0                      35.53
# 957                    20768200.0          41945.0                      35.74
# 958                    31509700.0          45362.0                      34.85
# 959                    15482400.0          23788.0                      34.99
# 960                    23310400.0          22970.0                      35.15
# 961                    23103400.0          33539.0                      35.37
# 962                    20924100.0          35673.0                      34.75
# 963                    20487100.0          27883.0                      34.90
# 964                    16965500.0          29848.0                      34.63
#
#      preco_melhor_oferta_compra  preco_medio  preco_minimo  preco_maximo  \
# 955                       36.11        36.41         36.11         37.00
# 956                       35.49        35.74         35.43         36.31
# 957                       35.72        35.78         35.52         36.26
# 958                       34.84        34.85         34.65         35.32
# 959                       34.91        34.90         34.63         35.14
# 960                       35.13        35.11         34.85         35.32
# 961                       35.35        35.36         34.90         35.52
# 962                       34.70        34.85         34.63         35.20
# 963                       34.88        34.81         34.57         34.97
# 964                       34.62        34.71         34.55         34.97
#
#      preco_abertura  num_distribuicao_papel  preco_ultimo_negocio  ...  \
# 955           36.60                   341.0                 36.11  ...
# 956           36.26                   342.0                 35.50  ...
# 957           35.87                   342.0                 35.72  ...
# 958           35.22                   342.0                 34.84  ...
# 959           34.69                   342.0                 34.91  ...
# 960           35.20                   342.0                 35.14  ...
# 961           34.93                   342.0                 35.35  ...
# 962           35.11                   342.0                 34.70  ...
# 963           34.71                   342.0                 34.89  ...
# 964           34.83                   342.0                 34.63  ...
#
#      razmedia20_60_preco_ultimo_negocio  razmedia60_120_preco_ultimo_negocio  \
# 955                            1.033913                             1.050209
# 956                            1.030670                             1.050605
# 957                            1.027441                             1.050737
# 958                            1.023165                             1.050503
# 959                            1.019612                             1.050385
# 960                            1.015833                             1.050267
# 961                            1.012349                             1.050053
# 962                            1.008343                             1.049503
# 963                            1.005014                             1.049196
# 964                            1.001511                             1.048666
#
#      razmedia120_240_preco_ultimo_negocio  \
# 955                              1.023293
# 956                              1.023005
# 957                              1.022809
# 958                              1.022606
# 959                              1.022394
# 960                              1.022204
# 961                              1.022086
# 962                              1.021899
# 963                              1.021705
# 964                              1.021461
#
#      razmedia240_480_preco_ultimo_negocio  \
# 955                              1.105378
# 956                              1.105962
# 957                              1.106683
# 958                              1.107262
# 959                              1.107819
# 960                              1.108366
# 961                              1.108924
# 962                              1.109467
# 963                              1.109937
# 964                              1.110227
#
#      razmedia20_120_preco_ultimo_negocio  razmedia60_240preco_ultimo_negocio  \
# 955                             1.085825                            1.074672
# 956                             1.082827                            1.074774
# 957                             1.079571                            1.074703
# 958                             1.074839                            1.074251
# 959                             1.070985                            1.073907
# 960                             1.066896                            1.073587
# 961                             1.063021                            1.073244
# 962                             1.058258                            1.072486
# 963                             1.054457                            1.071969
# 964                             1.050251                            1.071172
#
#      razmedia120_480preco_ultimo_negocio  razmedia20_240preco_ultimo_negocio  \
# 955                             1.131125                            1.111117
# 956                             1.131404                            1.107737
# 957                             1.131926                            1.104195
# 958                             1.132293                            1.099136
# 959                             1.132627                            1.094968
# 960                             1.132976                            1.090585
# 961                             1.133416                            1.086498
# 962                             1.133763                            1.081434
# 963                             1.134028                            1.077343
# 964                             1.134054                            1.072791
#
#      razmedia60_480preco_ultimo_negocio  razmedia20_480preco_ultimo_negocio
# 955                            1.187918                            1.228203
# 956                            1.188659                            1.225116
# 957                            1.189356                            1.221994
# 958                            1.189477                            1.217032
# 959                            1.189695                            1.213027
# 960                            1.189927                            1.208767
# 961                            1.190147                            1.204844
# 962                            1.189887                            1.199814
# 963                            1.189818                            1.195783
# 964                            1.189244                            1.191041
#
# [10 rows x 490 columns]

# %%
metadados = generate_metadata(data_itub4_clean)
metadados.head(30)
# Out:
#                                nome_variavel     tipo  qt_nulos  \
# 0               quantidade_papeis_negociados  float64         0
# 1                razmedia240_480_preco_medio  float64         0
# 2                razmedia120_240_preco_medio  float64         0
# 3                 razmedia60_120_preco_medio  float64         0
# 4                  razmedia20_60_preco_medio  float64         0
# 5                    razmin20_480preco_medio  float64         0
# 6                    razmin60_480preco_medio  float64         0
# 7                    razmin20_240preco_medio  float64         0
# 8                   razmin120_480preco_medio  float64         0
# 9                    razmin60_240preco_medio  float64         0
# 10                  razmin20_120_preco_medio  float64         0
# 11                 razmin240_480_preco_medio  float64         0
# 12                 razmin120_240_preco_medio  float64         0
# 13                razmedia20_120_preco_medio  float64         0
# 14                  razmin60_120_preco_medio  float64         0
# 15                   razmax20_480preco_medio  float64         0
# 16                   razmax60_480preco_medio  float64         0
# 17                   razmax20_240preco_medio  float64         0
# 18                  razmax120_480preco_medio  float64         0
# 19                   razmax60_240preco_medio  float64         0
# 20                  razmax20_120_preco_medio  float64         0
# 21                 razmax240_480_preco_medio  float64         0
# 22                 razmax120_240_preco_medio  float64         0
# 23                  razmax60_120_preco_medio  float64         0
# 24                   razmax20_60_preco_medio  float64         0
# 25  razmedia20_480preco_melhor_oferta_compra  float64         0
# 26  razmedia60_480preco_melhor_oferta_compra  float64         0
# 27                   razmin20_60_preco_medio  float64         0
# 28                 razmedia60_240preco_medio  float64         0
# 29                razmedia120_480preco_medio  float64         0
#
#     percent_nulos  cardinalidade
# 0             0.0            963
# 1             0.0            965
# 2             0.0            965
# 3             0.0            965
# 4             0.0            965
# 5             0.0            197
# 6             0.0            125
# 7             0.0            214
# 8             0.0             85
# 9             0.0            134
# 10            0.0            219
# 11            0.0             48
# 12            0.0             94
# 13            0.0            965
# 14            0.0            139
# 15            0.0            183
# 16            0.0            107
# 17            0.0            170
# 18            0.0             57
# 19            0.0             96
# 20            0.0            155
# 21            0.0             42
# 22            0.0             49
# 23            0.0             76
# 24            0.0            136
# 25            0.0            965
# 26            0.0            965
# 27            0.0            212
# 28            0.0            965
# 29            0.0            965

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data_itub4_clean,
                                                    target,
                                                    test_size=0.2,
                                                    random_state=42)
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-30fa910d5671> in <cell line: 1>()
# ----> 1 X_train, X_test, Y_train, Y_test = train_test_split(data_itub4_clean,
#       2                                                     target,
#       3                                                     test_size=0.2,
#       4                                                     random_state=42)
#       5 X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2780         raise ValueError("At least one array required as input")
#    2781
# -> 2782     arrays = indexable(*arrays)
#    2783
#    2784     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     512
#     513     result = [_make_indexable(X) for X in iterables]
# --> 514     check_consistent_length(*result)
#     515     return result
#     516
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     455     uniques = np.unique(lengths)
#     456     if len(uniques) > 1:
# --> 457         raise ValueError(
#     458             "Found input variables with inconsistent numbers of samples: %r"
#     459             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [965, 1686]

# %%
# FEATURE SELECTION
from sklearn.ensemble import RandomForestClassifier

X = X_train
y = Y_train

clf = RandomForestClassifier() # troque aqui qual classificador quer utilizar: GradientBoostingClassifier, DecisionTreeClassifier
clf.fit(X, y)

# Obter importância das variáveis
feature_importances = clf.feature_importances_
features = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances
})

# Ordenar variáveis por importância
features = features.sort_values(by='Importance', ascending=False)
features

predict = clf.predict(X_test)

from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, confusion_matrix, classification_report

print(confusion_matrix(Y_test, predict))
print(accuracy_score(Y_test, predict))
print(classification_report(Y_test, predict))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-23712de13f17> in <cell line: 8>()
#       6
#       7 clf = RandomForestClassifier() # troque aqui qual classificador quer utilizar: GradientBoostingClassifier, DecisionTreeClassifier
# ----> 8 clf.fit(X, y)
#       9
#      10 # Obter importância das variáveis
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     375         estimator = type(self.estimator)(criterion=self.criterion)
#     376         missing_values_in_feature_mask = (
# --> 377             estimator._compute_missing_values_in_feature_mask(
#     378                 X, estimator_name=self.__class__.__name__
#     379             )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in _compute_missing_values_in_feature_mask(self, X, estimator_name)
#     220         if not np.isfinite(overall_sum):
#     221             # Raise a ValueError in case of the presence of an infinite element.
# --> 222             _assert_all_finite_element_wise(X, xp=np, allow_nan=True, **common_kwargs)
#     223
#     224         # If the sum is not nan, then there are no missing values
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     170                 "#estimators-that-handle-nan-values"
#     171             )
# --> 172         raise ValueError(msg_err)
#     173
#     174
#
# ValueError: Input X contains infinity or a value too large for dtype('float32').
